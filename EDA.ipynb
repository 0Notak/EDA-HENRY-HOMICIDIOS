# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Lectura de los Datasets

# %%
dfh = pd.read_excel('homicidios.xlsx')
dfh.tail(2)
# Out:
#             ID  N_VICTIMAS      FECHA  AAAA  MM  DD      HORA  HH  \
# 694  2021-0096           1 2021-12-15  2021  12  15  10:30:00  10
# 695  2021-0097           1 2021-11-18  2021  11  18  06:10:00   6
#
#              LUGAR_DEL_HECHO TIPO_DE_CALLE  ...  Altura  Cruce  \
# 694       AV. EVA PERON 4071       AVENIDA  ...  4071.0    NaN
# 695  PADRE CARLOS MUJICA 709         CALLE  ...   709.0    NaN
#
#        Dirección Normalizada COMUNA                                XY (CABA)  \
# 694      PERON, EVA AV. 4071      9    Point (99324.54463985 97676.26932409)
# 695  PADRE CARLOS MUGICA 709      1  Point (107664.16647795 104708.63962087)
#
#             pos x         pos y   PARTICIPANTES    VICTIMA ACUSADO
# 694  -58.47066794  -34.65021673     AUTO-CARGAS       AUTO  CARGAS
# 695  -58.37976155  -34.58679619  BICICLETA-AUTO  BICICLETA    AUTO
#
# [2 rows x 21 columns]

# %%
dfl = pd.read_excel('lesiones.xlsx')
dfl.tail(2)
# Out:
#                     id  n_victimas  aaaa  mm  dd                fecha  \
# 23783  LC-2021-0652921           1  2021  12  31  2021-12-31 00:00:00
# 23784  LC-2020-0244615           1  2020   5  17            5/17/2020
#
#            hora franja_hora    direccion_normalizada comuna  ...  \
# 23783  22:00:00          22  LINIERS VIRREY y MORENO      5  ...
# 23784  21:00:00          21                       SD     SD  ...
#
#                 latutid victima             acusado            participantes  \
# 23783  -34.614288229345    MOTO  TRANSPORTE PUBLICO  MOTO-TRANSPORTE PUBLICO
# 23784       -3472890716    MOTO                AUTO                MOTO-AUTO
#
#       moto auto transporte_publico camion ciclista gravedad
# 23783    x    0                  x      0        0    GRAVE
# 23784    x    x                  0      0        0       SD
#
# [2 rows x 27 columns]

# %% [markdown]
# # Datos del SISTEMA NACIONAL DE INFORMACION NACIONAL

# %% [markdown]
# Datasets oficiales publicados por el gobierno argentino especificamente el
# SISTEMA NACIONAL DE INFORMACION NACIONAL
#
# Link:
# https://www.argentina.gob.ar/seguridad/estadisticascriminales/bases-de-datos

# %%
dfh2 = pd.read_excel('snic-pais.xlsx')
dfh2.head(10)
# Out:
#    anio codigo_delito_snic_id  \
# 0  2000                     1
# 1  2000                     2
# 2  2000                     3
# 3  2000                     4
# 4  2000                     5
# 5  2000                     6
# 6  2000                     7
# 7  2000                     8
# 8  2000                     9
# 9  2000                    10
#
#                          codigo_delito_snic_nombre  cantidad_hechos  \
# 0                               Homicidios dolosos             2653
# 1         Homicidios dolosos en grado de tentativa              884
# 2                     Muertes en accidentes viales             3686
# 3             Homicidios culposos por otros hechos             1058
# 4                                 Lesiones dolosas           107864
# 5           Lesiones culposas en Accidentes Viales            54429
# 6               Lesiones culposas por otros hechos            11024
# 7                Otros delitos contra las personas            21232
# ...

# %%
dfh3 = pd.read_excel('snic-provincias.xlsx')
dfh3.head(10)
# Out:
#    provincia_id                 provincia_nombre  anio codigo_delito_snic_id  \
# 0             2  Ciudad Autónoma de Buenos Aires  2000                     1
# 1             2  Ciudad Autónoma de Buenos Aires  2000                     2
# 2             2  Ciudad Autónoma de Buenos Aires  2000                     3
# 3             2  Ciudad Autónoma de Buenos Aires  2000                     4
# 4             2  Ciudad Autónoma de Buenos Aires  2000                     5
# 5             2  Ciudad Autónoma de Buenos Aires  2000                     6
# 6             2  Ciudad Autónoma de Buenos Aires  2000                     7
# 7             2  Ciudad Autónoma de Buenos Aires  2000                     8
# 8             2  Ciudad Autónoma de Buenos Aires  2000                     9
# 9             2  Ciudad Autónoma de Buenos Aires  2000                    10
#
#                          codigo_delito_snic_nombre  cantidad_hechos  \
# ...

# %% [markdown]
# # LEER ANTES DE COMENSAR A VER LOS ANALISIS

# %% [markdown]
# 1.- Se siguio la orden dada y se analizo en un EDA el dataset HOMICIDIOS de buenos aires principalmente
#
# 2.- como complementario el dataset de lesiones
#
# 3.- y aun mas como complemento 2 datasets del SNIC de argentina
#
# Al analisarse los 4 datasets de este documentos se sacaron las conclusiones que contiene este documento y despues se pusieron en el mismo asi que si se busca una idea general seria bueno terminar de leer el mismo

# %% [markdown]
# revisando los datos del dataset proporcionado, y los datos del SISTEMA DE INFORMACION NACIONAL, y por el nombre del delito del dataset PRINCIPAL que es HOMICIDIOS se sacan varias conclusiones apoyado de los datos del SNIC que son los datos oficiales, este analisis que se hiso no se tomo en cuenta la palabra HOMICIDIOS sino Muertes por accidentes viales, tambien al analisarlo, con los datos oficiales, se puede notar la diferencia de los valores ya que el primer dataset de apoyo es de ARGENTINA completo y el segundo solo de las provincias

# %% [markdown]
# Solo analisa los datos de acuerdo a como se proporcionaron especial y principalmente el primer dataset y tomando los demas como apoyo asique conforme a los datos que no proporciona el primer dataset y al ser tomado como principal es dificil hacer una afirmacion 100% concluyente deacuerdo a los datos proporcionados
#
# Asi que se presentan los datos y el analisis que se hiso referente a las consultas que se tomaron como importantes para el tema pedido.

# %% [markdown]
# #### Tipos de datos

# %% [markdown]
# Los datos numericos con los que se podian realizar operaciones era solo 1 que era la columna de N_VICTIMAS que son de variable cuantitativa discreta
#
# Y los demas como por ej LUGAR_DEL_HECHO, TIPO_DE CALLE, ACUSADO, VICTIMA son variables cualitativas que no permitian hacer operaciones con esos datos, solo por el conteo de los mismos era permitido por la naturaleza de los mismos.
#
# Pero como es un EDA y el tema principal es HOMICIDIOS no se realizaron mas calculos que los mostrados aqui ya que no se consideraron necesarios por falta de informacion en todo caso, solo hubieran servido en terminos especulativos.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # Analisis del Dataset de HOMICIDIOS VIALES

# %% [markdown]
# necesario leer estos 2 parrafos antes de comenzar a ver el analisis

# %% [markdown]
# ##### CABE ACLARAR QUE COMO HOMICIDIO SE REFIERE A UNA PERSONA TERMINANDO CON LA VIDA DE OTRA PERSONA, O EN SU CASO HOMICIDIO IMPRUDENTE, QUE ES UNA MUERTE CAUSADA POR OTRA PERSONA EN SU MAYORIA DE LOS CASOS ES DE CAUSA ACCIDENTEL PERO SE CATALOGA GRAVE SEGUN EL NIVEL DE IMPRUDENCIA

# %% [markdown]
#   .

# %% [markdown]
# .

# %% [markdown]
# ##### SE INICIA VIENDO EL TIPO DE DATOS QUE TIENE CADA COULUMNA DEL DATAFRAME PARA VER QUE TIPO DE OPERACION SE PUEDEN REALIZAR CON LA INFORMACION O SI ES NECESARIO UNA TRANFORMACION EN UN TIPO DE DATO PARA PODER TRABAJAR

# %%
dfh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     696 non-null    object
#  1   N_VICTIMAS             696 non-null    int64
#  2   FECHA                  696 non-null    datetime64[ns]
#  3   AAAA                   696 non-null    int64
#  4   MM                     696 non-null    int64
#  5   DD                     696 non-null    int64
#  6   HORA                   696 non-null    object
#  7   HH                     696 non-null    object
#  8   LUGAR_DEL_HECHO        696 non-null    object
#  9   TIPO_DE_CALLE          696 non-null    object
#  10  Calle                  695 non-null    object
#  11  Altura                 129 non-null    float64
#  12  Cruce                  525 non-null    object
#  13  Dirección Normalizada  688 non-null    object
# ...

# %% [markdown]
# #### SE HIZO UN RECUENTO DE DATOS FALTANTES QUE TIENE EL DATASET PARA VER EN QUE COLUMNA HAY FALTANTES Y SI PUEDE LLEGAR A INFLUIR AL MOMENTO DE HACER UNA OPERACION

# %% [markdown]
# conclusion: se puede  ver faltantes en Altura y Cruce principalmente, ya que son homicidios y no sabemos que es lo que ha ocurrido, el dato Altura podria ser de utilidad ya que podriamos ver en que parte de las calles ocurrio el Homicidio y asi ser mas especifico, para ver si la carretera tiene algun desperfecto o falta un semaforo o tambien si es un lugar peligroso. Para el caso del dato cruce es similar pero en este caso se refire a por que en ese cruce ocurren los homicidios identificando el lugar y conociendo el porque.
#
# Los datos son 696 y faltantes en Altura son 567 asi que utilizarlo para hacer un analisis utilizando todo el dataset resulta inviable solo podria utilizarse proximadamente 100 datos de esa columna para ese proposito, del mismo modo con la columna cruce  solo que aqui se encuentran mas datos, que en la columna anterior. conocer el lugar puede indicar el que es lo que sucede en el lugar como ya se menciono y por que suceden los homicidios

# %% [markdown]
# aclaracion: haciendo el analisis del tipo de base de datos que es se deduce que como es una Base de Datos Relacional, esta se rellena de con un solo formulario, osea que como base de datos relacional hecha en el modelo ACID (Mas que nada en el apartado de Atomicidad ya que cada fila es independiente de las demas y para ser rellenada no era necesario llenar todos los campos al igual que en la consistencia del dataset), esta no conto con normalizaciones para conseguir mas informacion, sino que se hiso lo mas practica posible con 1 sola tabla, esto se nota ya que si esta rellenada la columna de calle, se encuentra vacia la culumna altura ya que los datos mas adelante muestran que hay lugares como autopistas donde ese dato no se pudo rellenar y se marco como nulo, asi como si fue en un cruce la Altura tambien se quedo como nulo, y hubo un caso especial que hubo 1 nulo en calle que pudo haber terminado asi por el llenado del formato no por que la informacion, osea que no fue accidental sino dependio del lugar del hecho que determino si se llenaba el campo o no.

# %%
dfh.isnull().sum()
# Out:
# ID                         0
# N_VICTIMAS                 0
# FECHA                      0
# AAAA                       0
# MM                         0
# DD                         0
# HORA                       0
# HH                         0
# LUGAR_DEL_HECHO            0
# TIPO_DE_CALLE              0
# Calle                      1
# Altura                   567
# Cruce                    171
# Dirección Normalizada      8
# COMUNA                     0
# XY (CABA)                  0
# pos x                      0
# pos y                      0
# PARTICIPANTES              0
# VICTIMA                    0
# ACUSADO                    0
# dtype: int64

# %% [markdown]
# #### Analisis de Datos duplicados

# %% [markdown]
# 1.- El dataset incluye una columna que se llama ID que lleva una fecha en el mismo, solo por la presencia de esta columna no pueden haber datos duplicados ya que esta columna funciona como PK y no permite que existan datos duplicados en el mismo

# %% [markdown]
# counclusion: se aplico la funcion duplicated a todo el dataset ya que como se menciono en el apartado anterior es un analis hecho por filas no por columnas por el tipo de datos que contiene se deduce que es un base de datos relacional, y como mostro la funcion analisando todo el dataset no encontro duplicados ya que aunque si hubieron homicidios en los mismos lugares estos variaban en el dia o en la hora, tambien en los participantes del homicidio.
#
# Asi que se menciona que todos los datos son diferentes solo que se le podria llamar dato duplicado a en la misma calle, autopista, o la victima o causante son los mismos, pero no me encientro describiendo los datos es un analisis hecho con la informacion que se pueden extrar de ellos no sobre lo que lo que se puede decir sobre similitudes dentro de columnas especificas, asi que en este analisis la conclusion que se puede obtener que no hay datos duplicados

# %%
dfh.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### EL NUMERO DE VICTIMAS DEL DATASET DE HOMICIDIOS VIALES ES EL SIGUIENTE YA QUE UN REGISTRO EN LA BASE DE DATOS AVECES LLEVABA 2 HOMICIDIOS AUNQUE ESO NO ERA MUY COMUN

# %% [markdown]
# conclusion: muestra el total de homicidios viales que muestra el Dataset, no el numero de registros que contiene

# %%
dfh['N_VICTIMAS'].sum()
# Out:
# 717

# %% [markdown]
# #### EN LA SIGUIENTE CONSULTA SE MUESTRA LOS REGISTROS CON UN HOMICIDIO POR EVENTO

# %% [markdown]
# MUESTRA COMO HAY FALTANTES Y AVECES OCURRIO MAS DE 1 HOMICIDIO POR EVENTO, DEMUESTRA EL APARTADO ANTERIOR

# %%
dfh[dfh['N_VICTIMAS']== 1]['N_VICTIMAS'].count()
# Out:
# 676

# %% [markdown]
# # HOMICIDIOS POR AÑO

# %% [markdown]
# conclusion: solo se ve el numero de muertos por año, no dice el porque o como solucionarlo, pero puede servir para ver si el pais ha mejorado en sus numeros y muestra el nivel de mejora año a año (solo hay que tomar en cuenta la cuarentena provocada por el covid-19 y descartar si ha sido por la cuarentena o si varias calles en especifico mantuvieron el transito durante la pandemia ya sea por motivos economicos) esto ultimo se puede conseguir analisando calle por calle pero por falta de informacion no podemos ver el transito calle por calle de los lugares que necesitamos

# %%
dfha=dfh[['AAAA', 'N_VICTIMAS']].groupby(['AAAA']).sum()
dfha
# Out:
#       N_VICTIMAS
# AAAA
# 2016         146
# 2017         140
# 2018         149
# 2019         104
# 2020          81
# 2021          97

# %%
sns.catplot(data=dfha, x="AAAA", y="N_VICTIMAS", kind="bar", palette="coolwarm")
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_56836/3849922918.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dfha, x="AAAA", y="N_VICTIMAS", kind="bar", palette="coolwarm")

# %% [markdown]
# # Tipo de calle de los HOMICIDIOS

# %% [markdown]
# conclusion: podemos llegar a la conclusion que en las Avenidas han habido mas homicidios que en las Autopistas o Calles, asi que como se menciono anteriormente sobre los homicidios por imprudencia (ya que son HOMICIDIOS VIALES), se puede pensar que los homicidios no fueron por imprudencia ya que en las Avenidas se maneja con menor velocidad (la velocidad podria influir al momento de atropellar o chocar con alguien mas) asi que por el numero de muertes en un lugar como este se deduce solo que es poco probable que sea por falta de prudencia.
#
# Asi que no se afirma nada o niega nada por falta de informacion

# %%
dfht=dfh[['TIPO_DE_CALLE', 'N_VICTIMAS']].groupby(['TIPO_DE_CALLE']).sum()
dfht
# Out:
#                N_VICTIMAS
# TIPO_DE_CALLE
# AUTOPISTA              68
# AVENIDA               442
# CALLE                 138
# GRAL PAZ               69

# %%
sns.catplot(data=dfht, x="TIPO_DE_CALLE", y="N_VICTIMAS", kind="bar", palette="viridis")
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/1116490857.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dfht, x="TIPO_DE_CALLE", y="N_VICTIMAS", kind="bar", palette="viridis")

# %% [markdown]
# # QUE NUMERO DE HOMICIDIOS ESTUVIERON TALES PARTICIPANTES

# %% [markdown]
# conclusion: en el numero de muertos que hubo de mostro quien estubo presente mas no los acusados asi que por falta de informacion no se puede determinar que fue lo que sucedio para que se cometiera un Homicidio, pero se puede intuir mas no afirmar que los vehiculos de uso Publico de pasajeros asi como las motocicletas (que aparecen muchos) pudieron llegar a influir sobre estos Homicidios ya que manejan con imprudencia asi como los autos de carga de tambien aparecen.
#
# Ademas como se muestra la informacion ej moto-auto, se deduce que uno fue el causante y otro fueron los que cometieron el HOMICIDI0 (Lo repito por que es lo que tiene registrado el dataset  no muertes de cualquier tipo que ocurrieron en una carretera),
#
# asi que por el tipo de datos nos indica que  la mayoria de HOMICIDIOS EFECTIVAMENTE pudo haber sidos causados por IMPRUDENCIA.

# %%
dfhp=dfh[['PARTICIPANTES', 'N_VICTIMAS']].groupby(['PARTICIPANTES']).sum().sort_values(['N_VICTIMAS'], ascending=False).head(15)
dfhp
# Out:
#                   N_VICTIMAS
# PARTICIPANTES
# PEATON-PASAJEROS         105
# MOTO-AUTO                 84
# MOTO-CARGAS               80
# PEATON-AUTO               79
# MOTO-PASAJEROS            50
# MOTO-OBJETO FIJO          40
# PEATON-CARGAS             38
# AUTO-AUTO                 33
# PEATON-MOTO               30
# AUTO-OBJETO FIJO          28
# MOTO-MOTO                 25
# MULTIPLE                  17
# AUTO-CARGAS               15
# AUTO-PASAJEROS            10
# BICICLETA-CARGAS          10

# %%
sns.catplot(data=dfhp, x="PARTICIPANTES", y="N_VICTIMAS", kind="bar", palette="plasma")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/1562638433.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dfhp, x="PARTICIPANTES", y="N_VICTIMAS", kind="bar", palette="plasma")

# %% [markdown]
# # Numero de victimas

# %% [markdown]
# conclusion: Aqui los datos muestran quienes fueron los que murieron, asi que por los datos se puede intuir que muchos de los HOMICIDIOS fueron por imprudencia ya que las Motos aparecen e primer lugar.
#
# Solo que en segundo lugar se puede ver Peaton que de la manera en que fue registrada ej PEATON_MOTO que aparece se intulle como su nombre lo dice personas que caminaban en la calle, tambien como mencionaba en el grafico de lugar que mostraba avenida como principales lugares de homicidios y mas que nada por el alto numero de muertos, se puede intuir que pudo no haber sido muertes por Homicidio imprudente por parte de los conductores ya que las condiciones no lo permiten, aunque no se afirma nada por falta de informacion.
#
# Y viendolo del buen modo pudo haber sido por que las personas no respetan las señales de transito pero como es catalogado por el gobierno como HOMICIDIO, ellos no fueron los causantes de sus muertes si no hubieran sido catalogados como accidentes de transito no como  Homicidios, pero por falta de informacion no se puede asegurar nada es solo la intuicion por la clasificacion y la informacion de se supone que contiene el dataset.

# %%
dfhv=dfh[['VICTIMA', 'N_VICTIMAS']].groupby(['VICTIMA']).sum().sort_values(['N_VICTIMAS'], ascending=False).head(15)
dfhv
# Out:
#              N_VICTIMAS
# VICTIMA
# MOTO                302
# PEATON              266
# AUTO                 92
# BICICLETA            29
# SD                    9
# CARGAS                7
# PASAJEROS             5
# MOVIL                 3
# OBJETO FIJO           2
# PEATON_MOTO           2

# %%
sns.catplot(data=dfhv, x="VICTIMA", y="N_VICTIMAS", kind="bar", palette="plasma")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/3312150940.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dfhv, x="VICTIMA", y="N_VICTIMAS", kind="bar", palette="plasma")

# %% [markdown]
# # Acusados por Homicidios

# %% [markdown]
# conclusion: Por el numero de muertes y el tipo de causantes de los HOMICIDIOS se confirma que varios de estos no fueron accidentes ya que aqui señala pasajeros como causantes de los homicidios y como es posible que los pasajeros en este caso llegaran a lastimar a peatones como se mostro en la grafica anterior. O tambien que sean acusados los Motociclistas y personas que van en Bicicleta que aunque pudieron ser participantes repito participantes su vehiculo no permite asesinar a otra persona, solo por la columna en la que se encuentran estos datos que es acusado mas no participante se llego a esta conclusion (Aclaro el dataset no menciona que paso solo lo que paso que son los HOMICIDIOS)
#
# Aunque no se puede afirmar que es lo que sucedio respecto a los acusados como AUTO o CARGAS, solo que en autos de Carga son mas dificiles de manejar asi que se puede pensar como Homicidio por imprudencia.
#
# Pero en el caso de los AUTOS y en el alto numero de muertos en motocicleta de la grafica anterior, se piensa que si hay Homicidios por imprudencia tambien.

# %%
dfha=dfh[['ACUSADO', 'N_VICTIMAS']].groupby(['ACUSADO']).sum().sort_values(['N_VICTIMAS'], ascending=False).head(15)
dfha
# Out:
#              N_VICTIMAS
# ACUSADO
# AUTO                210
# PASAJEROS           178
# CARGAS              150
# OBJETO FIJO          67
# MOTO                 58
# SD                   23
# MULTIPLE             17
# BICICLETA             7
# OTRO                  6
# TREN                  1

# %%
sns.catplot(data=dfha, x="ACUSADO", y="N_VICTIMAS", kind="bar", palette="colorblind")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/392170030.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dfha, x="ACUSADO", y="N_VICTIMAS", kind="bar", palette="colorblind")

# %% [markdown]
# # Hora de los Homicidios

# %% [markdown]
# conclusion: el promedio de victimas dependiendo de la hora del dia se mantiene alto independientemente de si es de madrugada, mañana, tarde o noche, asi que se intuye que por el numero y tipo de involucrados deben haber diferentes factores que provocan los homicidios por ejemplo: peatones muertos en Horas de Mañana a madrugada en avenidas principalmente en horas de madrugada o mañana, y en la tarde, que es cuando principalmente las personas salen de su trabajo o entran a su trabajo.
#
# pero solo por los datos se puede deducir algo asi, pero en los datos no especifica que es lo que sucede asi que no se puede confirmar a el 100% las declaraciones

# %%
dfhh=dfh[['HH', 'N_VICTIMAS']].groupby(['HH']).sum().sort_values(['N_VICTIMAS'], ascending=False).head(15)
dfhh
# Out:
#     N_VICTIMAS
# HH
# 7           43
# 6           42
# 5           39
# 9           37
# 18          33
# 14          33
# 12          32
# 17          31
# 22          31
# 10          31
# 8           31
# 16          30
# 19          30
# 21          29
# 11          29

# %%
sns.catplot(data=dfhh, x="HH", y="N_VICTIMAS", kind="bar", palette="muted")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/3169423844.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dfhh, x="HH", y="N_VICTIMAS", kind="bar", palette="muted")

# %% [markdown]
# # Lugar de los HOMICIDIOS

# %% [markdown]
# conclusion: por el pequeño numero de eventos repetidos en los principales calles que muestra la siguiente consulta, se puede llegar a la conclusion de se puede sufrir un HOMICIDIO VIAL en cualquier calle practicamente osea que no hay una calle que sea considerada de peligro o de extremo peligro aunque si hay calles donde ocurrieron mas HOMICIDIOS no es un numero muy alto por mi para ser considerado de riesgo.
#
# Pero por la variabilidad y dispercion de los datos de donde sucedieron los eventos es como se llega a la conclusion de que puede pasar en cualquier lugar

# %%
dfhl=dfh[['LUGAR_DEL_HECHO', 'N_VICTIMAS']].groupby(['LUGAR_DEL_HECHO']).sum().sort_values(['N_VICTIMAS'], ascending=False).head(15)
dfhl
# Out:
#                                                     N_VICTIMAS
# LUGAR_DEL_HECHO
# AV 27 DE FEBRERO Y AV ESCALADA                               4
# AV. DR. TRISTAN ACHAVAL RODRIGUEZ Y BLVD. AZUCE...           3
# AV. GRAL. PAZ Y MACHAIN                                      2
# Rivadavia Av. y Pedernera                                    2
# Rabanal, Francisco, Intendente Av. y Saenz Av.               2
# Av. Gral. Paz e/ Ferre y Beron de Astrada                    2
# CANTILO, INT. Y UDAONDO, GUILLERMO AV.                       2
# SAN MARTIN AV. Y PUNTA ARENAS                                2
# NUEVA YORK Y ALTA GRACIA                                     2
# AV. PERITO MORENO Y FOURNIER                                 2
# Nazca Av. y Rivadavia Av.                                    2
# AV LA PLATA Y CNEL GREGORIO POMAR                            2
# Entre Rios Av. y Garay, Juan De Av.                          2
# DEL LIBERTADOR AV. 4100                                      2
# ...

# %%
sns.catplot(data=dfhl, x="N_VICTIMAS", y="LUGAR_DEL_HECHO", kind="bar", palette="cividis")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/2197111977.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dfhl, x="N_VICTIMAS", y="LUGAR_DEL_HECHO", kind="bar", palette="cividis")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/axisgrid.py:123: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Hora Exacta de los Homicidios

# %% [markdown]
# conclusion: de la siguiente consulta se puede ver la hora exacta en la que se tomaron los registros de los datos a diferencia de la grafica anterior que solo mostraba la hora aqui se puede ver con un poco mas de precision
#
# la diferencia de esta consulta a la anterior es que como la funcion solo revisaba el numero de eventos repetidos que ocurrian al haber diferencias en los minutos, se movio el resultado ya que esta consulta mostro que si hay horas especificas del dia que ocurren mas que otras.
#
# Que aunque al ser numeros no tan grandes no se puede afirmar absolutamente nada, se recomienda tomar con mas importancia el grafico anterior que solo mostraba la hora de los eventos ya que aunque no arroje tanta presicion del evento puede dar mas informacion respecto a el tema de este detaset que son Homicidios Viales ya que no existe un minuto especifico en el dia en que ocurren estos eventos es mejor verlos por hora.

# %%
dfh['HORA'].value_counts().head(15)
# Out:
# HORA
# 16:00:00    10
# 14:00:00    10
# 21:00:00     9
# 08:00:00     9
# 09:00:00     9
# 12:30:00     8
# 03:30:00     8
# 07:30:00     8
# 05:30:00     8
# 22:00:00     7
# 11:00:00     7
# 20:00:00     7
# 05:00:00     7
# 15:30:00     6
# 06:40:00     6
# Name: count, dtype: int64

# %% [markdown]
# #### Conclusion general

# %% [markdown]
# Se puede ver el tipo de involucrados como el de victimas asi como las horas del dia y donde ocurrio y aun asi no saber que es lo que paso por la palabra HOMICIDIO puede ser malentendida tomada como muertes por accidentes viales o no, pero con los demas datos que sirven como complemento nos podemos dar una idea de la situacion de buenos aires respecto a la informacion proporcionada en el Dataset Homicidios

# %% [markdown]
# # Datasets Lesiones

# %%
dfl.head(10)
# Out:
#                 id  n_victimas  aaaa  mm  dd                fecha      hora  \
# 0  LC-2019-0000179           1  2019   1   1  2019-01-01 00:00:00  09:00:00
# 1  LC-2019-0000053           1  2019   1   1  2019-01-01 00:00:00  01:55:00
# 2  LC-2019-0000063           1  2019   1   1  2019-01-01 00:00:00  02:00:00
# 3  LC-2019-0000079           1  2019   1   1  2019-01-01 00:00:00  02:30:00
# 4  LC-2019-0000082           4  2019   1   1  2019-01-01 00:00:00  04:30:00
# 5  LC-2019-0000136           2  2019   1   1  2019-01-01 00:00:00  08:05:00
# 6  LC-2019-0000142           1  2019   1   1  2019-01-01 00:00:00  07:30:00
# 7  LC-2019-0000194           1  2019   1   1  2019-01-01 00:00:00  07:15:00
# 8  LC-2019-0000202           1  2019   1   1  2019-01-01 00:00:00  09:36:00
# 9  LC-2019-0000329           1  2019   1   1  2019-01-01 00:00:00  12:24:00
#
#   franja_hora direccion_normalizada comuna  ...     latutid   victima acusado  \
# ...

# %% [markdown]
# ####  A el igual que el dataset anterior se tomo todo el dataset para ver duplicados ya que como se puedever este dataset tiene hasta una columna que se llama ID que tiene la funcion de ver datos duplicados como tal.

# %% [markdown]
# aclaracion con datos duplicados no me refiero a datos en colunas duplicadas como un conteo de datos sino por evento osea por fila no por columna el analisis por columna se realizara mas a delante

# %%
dfl.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Valores Nulos del dataset

# %% [markdown]
# conclusion: En el dataset se puede ver que dejaron valores nulos, asi como se pueden ver datos con el nombre de SD, aunque por el tipo de dataset que es solo lesiones, no se le puede exigir mucho ya que no es informacion de alta reelevancia asi que puede ser que no fuera obligatorio llenar muchos de estos datos para no sobrecargar la base de datos o simplemente por que no eran necesarios.

# %%
dfl.isnull().sum()
# Out:
# id                           0
# n_victimas                   0
# aaaa                         0
# mm                           0
# dd                           0
# fecha                        0
# hora                         0
# franja_hora                  5
# direccion_normalizada       53
# comuna                     169
# tipo_calle                   0
# otra_direccion               0
# calle                    10918
# altura                   11014
# cruce                    14378
# geocodificacion_CABA        39
# longitud                   262
# latutid                    262
# victima                      0
# acusado                      0
# participantes                0
# moto                        93
# auto                        93
# transporte_publico          93
# camion                      93
# ciclista                    93
# gravedad                     0
# dtype: int64

# %% [markdown]
# # Años con mas lesionados

# %% [markdown]
# conclusion: A el igual que en el dataset anterior se puede ver una disminucion de los lesionados a el pasar de los años (pero hay que tomar en cuenta la pandemia), y como se menciono anteriormente tenia que verse el trafico de personas en los años de cuaterntena, pero al disminuir tambien los lesionados indica que la cuarentena  es la causante de la dsiminucion de ambos casos ya que se vio el mismo comportamiento en este segundo dataset.

# %%
dfla=dfl[['aaaa', 'n_victimas']].groupby(['aaaa']).sum().sort_values(['n_victimas'], ascending=False).head(15)
dfla
# Out:
#       n_victimas
# aaaa
# 2019       11792
# 2021        8957
# 2020        6855

# %%
sns.catplot(data=dfla, x="aaaa", y="n_victimas", kind="bar", palette="cividis")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/2610260032.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dfla, x="aaaa", y="n_victimas", kind="bar", palette="cividis")

# %% [markdown]
# # Meses con mas lesionados

# %% [markdown]
# conclusion: aqui se tomo los datos de todos los años pero solo se realizo la operacion por mes ya que se buscaba ver dentro de los años las fechas con mas lesionados y ver una relacion con respecto a dias festivos
#
# en la tabla que se encuentra ordenado de mayor a menor no se ve una relacion entre los datos, pero en el grafico de la tabla se ve un ascenso mes a mes hasta alcanzar un pico ej de Enero a Marzo despues una disminucion paulatina hasta mayo y asi en los datos con subidas y bajadas, que nos puede indicar probables sucesos sociales que suceden en argentina que explique estas subidad y bajadas
#
# no puedo decir con certesa que es lo que sucede esos meses ya que desconosco los eventos sociales argentinos "Lo siento"

# %%
dflm=dfl[['mm', 'n_victimas']].groupby(['mm']).sum().sort_values(['n_victimas'], ascending=False).head(15)
dflm
# Out:
#     n_victimas
# mm
# 10        2762
# 3         2501
# 12        2474
# 8         2420
# 9         2363
# 7         2360
# 2         2290
# 1         2229
# 6         2153
# 11        2126
# 4         2034
# 5         1892

# %%
sns.catplot(data=dflm, x="mm", y="n_victimas", kind="bar", palette="BrBG")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/3017536716.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dflm, x="mm", y="n_victimas", kind="bar", palette="BrBG")

# %% [markdown]
# # Victimas que resultaron lesionadas

# %% [markdown]
# conclusion: se puede ver el mayor numero de lesionados con los motociclistas, autos, motos, peaton, etc. Van en secuencia de nivel de riesgo que en este caso seria 1.Moto, seguido de lo mas comun que es 2.Auto, hasta lo menos comun

# %%
dflv=dfl[['victima', 'n_victimas']].groupby(['victima']).sum().sort_values(['n_victimas'], ascending=False).head(15)
dflv[1:]
# Out:
#                     n_victimas
# victima
# MOTO                      5927
# AUTO                      2606
# CICLISTA                  2263
# PEATON                    2157
# TRANSPORTE PUBLICO         905
# CAMIONETA                  257
# TAXI                       247
# MOVIL                      139
# MIXTO                      113
# CAMION                      96
# MONOPATIN                   28
# OTRO                        26
# UTILITARIO                  16

# %%
sns.catplot(data=dflv[1:], x="victima", y="n_victimas", kind="bar", palette="RdBu")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_56836/2345833887.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dflv[1:], x="victima", y="n_victimas", kind="bar", palette="RdBu")

# %% [markdown]
# # Hora de los accidentes

# %% [markdown]
# conclusion: aunque las horas como se señalo en el el dataset anterior es muy especifico nos puede dar una idea ya que aqui las victimas por horas es mas que en el Dataset anterior, en este caso puede servir como punto de referencia de a que hora ocurren los accidentes

# %%
dflh=dfl[['hora', 'n_victimas']].groupby(['hora']).sum().sort_values(['n_victimas'], ascending=False).head(15)
dflh
# Out:
#           n_victimas
# hora
# 00:00:00         389
# 16:00:00         337
# 12:00:00         314
# 18:00:00         310
# 17:00:00         306
# 15:00:00         301
# 14:00:00         284
# 13:00:00         283
# 12:30:00         254
# 19:00:00         249
# 16:30:00         247
# 15:30:00         246
# 17:30:00         245
# 18:30:00         233
# 13:30:00         233

# %%
sns.catplot(data=dflh, x="hora", y="n_victimas", kind="bar", palette="deep")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/1029911646.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dflh, x="hora", y="n_victimas", kind="bar", palette="deep")

# %% [markdown]
# # ACUSADOS o causantes de lesiones

# %% [markdown]
# conclusion: se puede ver con claridad como los transportes mas comunes son los reponsables de los lesionados asi hasta lo menos comun.
#
# Esto nos demuestra el nivel de peatones que son causantes de accidentes y refuerza la teoria del dataset de Homicidios donde nos muestra una aparicion de los peatones en acusados como en participantes sobre el comportamiento real de los peatones en argentina y que puede servir para descartar suposiciones ya que involucran los mismos años

# %%
dflac=dfl[['acusado', 'n_victimas']].groupby(['acusado']).sum().sort_values(['n_victimas'], ascending=False).head(15)
dflac[1:]
# Out:
#                     n_victimas
# acusado
# AUTO                      5169
# TRANSPORTE PUBLICO        1188
# CAMIONETA                  987
# MOTO                       750
# TAXI                       648
# CAMION                     348
# OBJETO FIJO                332
# MOVIL                       99
# CICLISTA                    90
# UTILITARIO                  29
# OTRO                        25
# PEATON                      16
# MONOPATIN                    3

# %%
sns.catplot(data=dflac[1:], x="acusado", y="n_victimas", kind="bar", palette="plasma")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_56836/1380175839.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dflac[1:], x="acusado", y="n_victimas", kind="bar", palette="plasma")

# %% [markdown]
# # Gravedad de las lesiones

# %% [markdown]
# conclusion: Se puede ver que la cantidad de lesiones solo ha llegado hasta grave y no fatal y como son los que estan catalogados en el Dataset tambien se encuentran los datos SD que al no tomarse como graves o fatales se hace la suposicion de que no fueron graves o fatales las lesiones por eso no fue necesario registrarlo.

# %%
dflg=dfl[['gravedad', 'n_victimas']].groupby(['gravedad']).sum().sort_values(['n_victimas'], ascending=False).head(15)
dflg
# Out:
#           n_victimas
# gravedad
# SD             26694
# GRAVE            808
# sd                95
# FATAL              5
# grave              2

# %%
sns.catplot(data=dflg, x="gravedad", y="n_victimas", kind="bar", palette="plasma")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_56836/3848924395.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dflg, x="gravedad", y="n_victimas", kind="bar", palette="plasma")

# %% [markdown]
# # Lesionados por comuna

# %% [markdown]
# conclusion: Se puede ver la localizacion de los accidentes por comuna y asi ver en que comuna ocurren mas eventos como estos

# %%
dflc=dfl[['comuna', 'n_victimas']].groupby(['comuna']).sum().sort_values(['n_victimas'], ascending=False).head(15)
dflc
# Out:
#         n_victimas
# comuna
# 1             2838
# 15            2192
# 4             2134
# 9             2075
# 3             1957
# 14            1803
# 7             1757
# 12            1711
# 11            1612
# 13            1550
# 10            1538
# 5             1378
# 8             1353
# 6             1082
# 2              996

# %%
sns.catplot(data=dflc, x="comuna", y="n_victimas", kind="bar", palette="inferno")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/467002539.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=dflc, x="comuna", y="n_victimas", kind="bar", palette="inferno")

# %% [markdown]
# # DATASETS COMPLEMENTARIOS

# %%
dfh2.head(15)
# Out:
#     anio codigo_delito_snic_id  \
# 0   2000                     1
# 1   2000                     2
# 2   2000                     3
# 3   2000                     4
# 4   2000                     5
# 5   2000                     6
# 6   2000                     7
# 7   2000                     8
# 8   2000                     9
# 9   2000                    10
# 10  2000                    11
# 11  2000                    12
# 12  2000                    13
# 13  2000                    14
# 14  2000                    15
#
#                             codigo_delito_snic_nombre  cantidad_hechos  \
# 0                                  Homicidios dolosos             2653
# 1            Homicidios dolosos en grado de tentativa              884
# 2                        Muertes en accidentes viales             3686
# 3                Homicidios culposos por otros hechos             1058
# 4                                    Lesiones dolosas           107864
# ...

# %%
dfh3.head(15)
# Out:
#     provincia_id                 provincia_nombre  anio codigo_delito_snic_id  \
# 0              2  Ciudad Autónoma de Buenos Aires  2000                     1
# 1              2  Ciudad Autónoma de Buenos Aires  2000                     2
# 2              2  Ciudad Autónoma de Buenos Aires  2000                     3
# 3              2  Ciudad Autónoma de Buenos Aires  2000                     4
# 4              2  Ciudad Autónoma de Buenos Aires  2000                     5
# 5              2  Ciudad Autónoma de Buenos Aires  2000                     6
# 6              2  Ciudad Autónoma de Buenos Aires  2000                     7
# 7              2  Ciudad Autónoma de Buenos Aires  2000                     8
# 8              2  Ciudad Autónoma de Buenos Aires  2000                     9
# 9              2  Ciudad Autónoma de Buenos Aires  2000                    10
# 10             2  Ciudad Autónoma de Buenos Aires  2000                    11
# ...

# %% [markdown]
# # DETECCION DE NULOS EN LOS DATASETS

# %% [markdown]
# conclusion: hay datos que en los delitos no incluye por ejemplo si son hombres o mujeres asi que omitieron llenar el campo, como por ejemplo en robos no hay homicidios solo hay hechos

# %%
dfh2.isnull().sum()
# Out:
# anio                           0
# codigo_delito_snic_id          0
# codigo_delito_snic_nombre      0
# cantidad_hechos                0
# cantidad_victimas            579
# cantidad_victimas_masc       579
# cantidad_victimas_fem        579
# cantidad_victimas_sd         579
# tasa_hechos                    0
# tasa_victimas                579
# tasa_victimas_masc           579
# tasa_victimas_fem            579
# dtype: int64

# %%
dfh3.isnull().sum()
# Out:
# provincia_id                     0
# provincia_nombre                 0
# anio                             0
# codigo_delito_snic_id            0
# codigo_delito_snic_nombre        0
# cantidad_hechos                  0
# cantidad_victimas            13736
# cantidad_victimas_masc       13736
# cantidad_victimas_fem        13736
# cantidad_victimas_sd         13736
# tasa_hechos                      0
# tasa_victimas                13736
# tasa_victimas_masc           13736
# tasa_victimas_fem            13736
# dtype: int64

# %% [markdown]
# # En datos duplicados se hiso el mismo analisis de duplicados

# %% [markdown]
# conclusion: como se encuentran diferentes comunas y delitos por año ademas de fechas no se encuentran duplicados buscando en filas mas no en columnas

# %%
dfh2.duplicated().sum()
# Out:
# 0

# %%
dfh3.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Numero oficial de muertos por accidentes viales

# %% [markdown]
# conclusion: se puede ver el numero de muertos por accidentes viales y la comparacion se hiso con el dataset de HOMICIDIOS proporcionado
#
# se puede ver la comparacion con los años del 2016 a 2021 con el otro dataset, no se hace la comparativa por que el analisis principal se basa en el dataset proporcionado no en este que aunque es el oficial con los datos especificados por ej: la diferencia entre Homicidios y Muertes en accidentes viales.

# %%
dfh2a=dfh2[dfh2['codigo_delito_snic_nombre']== 'Muertes en accidentes viales']
dfh2a
# Out:
#      anio codigo_delito_snic_id     codigo_delito_snic_nombre  \
# 2    2000                     3  Muertes en accidentes viales
# 33   2001                     3  Muertes en accidentes viales
# 64   2002                     3  Muertes en accidentes viales
# 95   2003                     3  Muertes en accidentes viales
# 126  2004                     3  Muertes en accidentes viales
# 157  2005                     3  Muertes en accidentes viales
# 188  2006                     3  Muertes en accidentes viales
# 219  2007                     3  Muertes en accidentes viales
# 250  2008                     3  Muertes en accidentes viales
# 281  2009                     3  Muertes en accidentes viales
# 312  2010                     3  Muertes en accidentes viales
# 343  2011                     3  Muertes en accidentes viales
# 374  2012                     3  Muertes en accidentes viales
# 405  2013                     3  Muertes en accidentes viales
# ...

# %% [markdown]
# # Toma de muestra para comparacion

# %% [markdown]
# se pueden ver las victimas por año de argentina en el Apartado de muertes en accidentes viales para hacer una estimacion general de este suceso ocurrido a nivel general

# %%
dfh2a[['anio', 'codigo_delito_snic_id', 'codigo_delito_snic_nombre', 'cantidad_victimas']][16:22]
# Out:
#      anio codigo_delito_snic_id     codigo_delito_snic_nombre  \
# 498  2016                     3  Muertes en accidentes viales
# 538  2017                     3  Muertes en accidentes viales
# 598  2018                     3  Muertes en accidentes viales
# 658  2019                     3  Muertes en accidentes viales
# 718  2020                     3  Muertes en accidentes viales
# 778  2021                     3  Muertes en accidentes viales
#
#      cantidad_victimas
# 498             4302.0
# 538             4730.0
# 598             4803.0
# 658             4189.0
# 718             2983.0
# 778             3827.0

# %% [markdown]
# # Cantidad de victimas por diferentes causas en Argentina por año

# %% [markdown]
# conclusion: viendo el primer dataframe de estos datasets de apoyo se pueden notar los diferentes delitos que se han cometido en argentina aqui lo que se hiso fue sumarlos para conseguir el numero de personas que han sufrido percanses que van desde homicidios, robos o delitos sexuales para intentar ver el nivel de seguridad de argentina por año
#
# Pero como no es objetivo el analisis de este dataset no se profundiza en estos delitos u en lo ocurrido en otros años

# %%
nummuertos = dfh2[['anio' ,'cantidad_victimas', 'cantidad_victimas_masc', 'cantidad_victimas_fem', 'cantidad_victimas_sd',"tasa_victimas","tasa_victimas_masc", "tasa_victimas_fem"]].groupby(['anio']).sum()
nummuertos
# Out:
#       cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# anio
# 2000           245383.0                114108.0                72766.0
# 2001           256936.0                123640.0                78939.0
# 2002           252258.0                117746.0                77784.0
# 2003           262200.0                122845.0                82490.0
# 2004           284939.0                134441.0                92381.0
# 2005           295160.0                138557.0                96364.0
# 2006           314909.0                144989.0               103763.0
# 2007           339866.0                154108.0               107408.0
# 2008           354406.0                169943.0               116817.0
# 2009           353762.0                114343.0                82377.0
# 2010           353149.0                114985.0                83339.0
# 2011           379735.0                117842.0                84430.0
# ...

# %%
nummuertos.plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Cantidad de victimas por genero

# %% [markdown]
# conclusion: se puede ver la grafica de victimas por año, genero y tambien los que no hay datos de ellos.

# %%
numcm=nummuertos[['cantidad_victimas_masc', 'cantidad_victimas_fem', 'cantidad_victimas_sd']]
numcm
# Out:
#       cantidad_victimas_masc  cantidad_victimas_fem  cantidad_victimas_sd
# anio
# 2000                114108.0                72766.0               58520.0
# 2001                123640.0                78939.0               54357.0
# 2002                117746.0                77784.0               56728.0
# 2003                122845.0                82490.0               56865.0
# 2004                134441.0                92381.0               58117.0
# 2005                138557.0                96364.0               60239.0
# 2006                144989.0               103763.0               66157.0
# 2007                154108.0               107408.0               78350.0
# 2008                169943.0               116817.0               67646.0
# 2009                114343.0                82377.0              114163.0
# 2010                114985.0                83339.0              111322.0
# 2011                117842.0                84430.0              133385.0
# ...

# %%
numcm.plot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Columnas con los registros mas altos que delito fueron y en que año

# %% [markdown]
# conclusion: en las siguientes consultas se puede ver que delitos fueron los que mayor numero registraron y esto sive para dar una idea rapida mas no completa de la grafica anterior donde se mostraron los registros por año y genero

# %% [markdown]
# analisis: principalmente ocupan primeros lugares lesiones dolosas entre hombres y mujeres(se aclara que no solo las sufrieron las mujeres sino tambien los hombres), tambien lo que genero mas HECHOS o registros sin necesariamente VICTIMAS son los robos y en años se ven muy dispersos los años asi que en picos de violencia no se puede catalogar un año como con los registros mas altos si no varios

# %%
dfh2.iloc[dfh2[['cantidad_hechos']].idxmax()]
# Out:
#      anio codigo_delito_snic_id  \
# 673  2019                    15
#
#                              codigo_delito_snic_nombre  cantidad_hechos  \
# 673  Robos (excluye los agravados por el resultado ...           473682
#
#      cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 673                NaN                     NaN                    NaN
#
#      cantidad_victimas_sd  tasa_hechos  tasa_victimas  tasa_victimas_masc  \
# 673                   NaN  1054.062256            NaN                 NaN
#
#      tasa_victimas_fem
# 673                NaN

# %%
dfh2.iloc[dfh2[['cantidad_victimas']].idxmax()]
# Out:
#      anio codigo_delito_snic_id codigo_delito_snic_nombre  cantidad_hechos  \
# 438  2014                     5          Lesiones dolosas           170921
#
#      cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 438           184038.0                 68857.0                83791.0
#
#      cantidad_victimas_sd  tasa_hechos  tasa_victimas  tasa_victimas_masc  \
# 438               31390.0   400.569489     431.310425          329.519196
#
#      tasa_victimas_fem
# 438         384.833771

# %%
dfh2.iloc[dfh2[['cantidad_victimas_masc']].idxmax()]
# Out:
#      anio codigo_delito_snic_id codigo_delito_snic_nombre  cantidad_hechos  \
# 252  2008                     5          Lesiones dolosas           146338
#
#      cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 252           154360.0                 73586.0                58955.0
#
#      cantidad_victimas_sd  tasa_hechos  tasa_victimas  tasa_victimas_masc  \
# 252               21819.0   366.286743     386.365967          376.585358
#
#      tasa_victimas_fem
# 252         288.833374

# %%
dfh2.iloc[dfh2[['cantidad_victimas_fem']].idxmax()]
# Out:
#      anio codigo_delito_snic_id codigo_delito_snic_nombre  cantidad_hechos  \
# 840  2022                     5          Lesiones dolosas           166984
#
#      cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 840           177390.0                 64098.0                97111.0
#
#      cantidad_victimas_sd  tasa_hechos  tasa_victimas  tasa_victimas_masc  \
# 840               16181.0   361.164948     383.671783          282.252197
#
#      tasa_victimas_fem
# 840         412.792969

# %%
dfh2.iloc[dfh2[['tasa_victimas']].idxmax()]
# Out:
#      anio codigo_delito_snic_id codigo_delito_snic_nombre  cantidad_hechos  \
# 438  2014                     5          Lesiones dolosas           170921
#
#      cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# 438           184038.0                 68857.0                83791.0
#
#      cantidad_victimas_sd  tasa_hechos  tasa_victimas  tasa_victimas_masc  \
# 438               31390.0   400.569489     431.310425          329.519196
#
#      tasa_victimas_fem
# 438         384.833771

# %% [markdown]
# # Estadistica

# %% [markdown]
# conclusion: se ve el promedio de personas afectadas en los diferentes delitos como su distribucion en el termino de cuartiles donde la mayoria se concentra en el 3 cuartil que marca el 75%, tambien se ve que la desviacion estandar no es muy grande por lo que se concluye que no hay mucha dispercion en los datos osea que no estan muy alejados de la media atravez de los años

# %%
numprob=nummuertos.describe()
numprob
# Out:
#        cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# count          23.000000               23.000000              23.000000
# mean       345993.086957           140700.043478          117837.782609
# std         54852.204185            24320.064269           40814.673706
# min        245383.000000            97378.000000           72766.000000
# 25%        305034.500000           117794.000000           82433.500000
# 50%        354406.000000           143769.000000          103763.000000
# 75%        389168.000000           161782.500000          155060.000000
# max        424151.000000           174823.000000          208075.000000
#
#        cantidad_victimas_sd  tasa_victimas  tasa_victimas_masc  \
# count              23.00000      23.000000           23.000000
# mean            76270.73913     832.715902          693.436568
# std             27536.38895      87.315471          100.229262
# min             48487.00000     669.321591          471.495114
# ...

# %%
numprob.plot(kind='bar')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## DELITOS POR PROVINCIA

# %%
dfh3.head(15)
# Out:
#     provincia_id                 provincia_nombre  anio codigo_delito_snic_id  \
# 0              2  Ciudad Autónoma de Buenos Aires  2000                     1
# 1              2  Ciudad Autónoma de Buenos Aires  2000                     2
# 2              2  Ciudad Autónoma de Buenos Aires  2000                     3
# 3              2  Ciudad Autónoma de Buenos Aires  2000                     4
# 4              2  Ciudad Autónoma de Buenos Aires  2000                     5
# 5              2  Ciudad Autónoma de Buenos Aires  2000                     6
# 6              2  Ciudad Autónoma de Buenos Aires  2000                     7
# 7              2  Ciudad Autónoma de Buenos Aires  2000                     8
# 8              2  Ciudad Autónoma de Buenos Aires  2000                     9
# 9              2  Ciudad Autónoma de Buenos Aires  2000                    10
# 10             2  Ciudad Autónoma de Buenos Aires  2000                    11
# ...

# %% [markdown]
# ### ANALISIS DE REGISTROS DE DELITOS DIFERENTES POR PROVINCIA

# %% [markdown]
# conclusion: se pueden ver las provincias que se encuentran en el dataset

# %%
dfh3u=dfh3['provincia_nombre'].unique()
dfh3u
# Out:
# array(['Ciudad Autónoma de Buenos Aires', 'Buenos Aires', 'Catamarca',
#        'Córdoba', 'Corrientes', 'Chaco', 'Chubut', 'Entre Ríos',
#        'Formosa', 'Jujuy', 'La Pampa', 'La Rioja', 'Mendoza', 'Misiones',
#        'Neuquén', 'Río Negro', 'Salta', 'San Juan', 'San Luis',
#        'Santa Cruz', 'Santa Fe', 'Santiago del Estero', 'Tucumán',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur'],
#       dtype=object)

# %% [markdown]
# # Cantidad de eventos por provincia

# %% [markdown]
# analisis: se hiso el analisis del dataset por eventos agrupados por la provincia, para ver que provincia presentaba mas sucesos

# %%
hprovincia=dfh3[['provincia_nombre', 'cantidad_victimas', 'cantidad_victimas_masc', 'cantidad_victimas_fem', 'cantidad_victimas_sd', 'tasa_victimas', 'tasa_victimas_masc','tasa_victimas_fem']].groupby(['provincia_nombre']).sum()
hprovincia
# Out:
#                                                     cantidad_victimas  \
# provincia_nombre
# Buenos Aires                                                1959539.0
# Catamarca                                                    148764.0
# Chaco                                                        120994.0
# Chubut                                                        97329.0
# Ciudad Autónoma de Buenos Aires                              818632.0
# Corrientes                                                   112548.0
# Córdoba                                                      932555.0
# Entre Ríos                                                   202177.0
# Formosa                                                      115595.0
# Jujuy                                                        121236.0
# La Pampa                                                      47018.0
# La Rioja                                                      63400.0
# ...

# %%
hpc=hprovincia[['cantidad_victimas']].sort_values(['cantidad_victimas'], ascending=False)
hpc
# Out:
#                                                     cantidad_victimas
# provincia_nombre
# Buenos Aires                                                1959539.0
# Córdoba                                                      932555.0
# Santa Fe                                                     830189.0
# Ciudad Autónoma de Buenos Aires                              818632.0
# Mendoza                                                      686608.0
# Salta                                                        371524.0
# Tucumán                                                      316391.0
# Entre Ríos                                                   202177.0
# Santiago del Estero                                          154416.0
# Catamarca                                                    148764.0
# Jujuy                                                        121236.0
# Chaco                                                        120994.0
# ...

# %% [markdown]
# # Analisis de sucesos por Provincia

# %% [markdown]
# se pueden ver las provincias con mayor numero de incidentes ordenados para ver

# %%
sns.catplot(data=hpc, x="provincia_nombre", y="cantidad_victimas", kind="bar", palette="inferno")
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/w5/r6_nbnhj29l7td33bhmpmz180000gn/T/ipykernel_726/534397797.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=hpc, x="provincia_nombre", y="cantidad_victimas", kind="bar", palette="inferno")

# %% [markdown]
# # Cantidad de sucesos por año

# %% [markdown]
# analisis; en el grafico se puede ver que no hay una variacion muy grande en los sucesos ocurridos en Argentina incluso tomando encuenta los años de la cuarentena

# %%
hanio=dfh3[['anio', 'cantidad_victimas', 'cantidad_victimas_masc', 'cantidad_victimas_fem', 'cantidad_victimas_sd', 'tasa_victimas', 'tasa_victimas_masc','tasa_victimas_fem']].groupby(['anio']).sum()
hanio
# Out:
#       cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# anio
# 2000           245383.0                114108.0                72766.0
# 2001           256936.0                123640.0                78939.0
# 2002           252258.0                117746.0                77784.0
# 2003           262200.0                122845.0                82490.0
# 2004           284939.0                134441.0                92381.0
# 2005           295160.0                138557.0                96364.0
# 2006           314909.0                144989.0               103763.0
# 2007           339866.0                154108.0               107408.0
# 2008           354406.0                169943.0               116817.0
# 2009           310883.0                114343.0                82377.0
# 2010           309646.0                114985.0                83339.0
# 2011           335657.0                117842.0                84430.0
# ...

# %%
gvictimas=hanio[['cantidad_victimas', 'cantidad_victimas_masc', 'cantidad_victimas_fem']]

# %%
gvictimas.plot(kind='bar')
plt.style.use("Solarize_Light2")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Analisis estadistico de provincias

# %% [markdown]
# se hiso una comparativa con el dataset anterior el que no incluia provincias, y mostro resultados diferentes, asi que no se realizo un nuevo analisis de las diferencias entre estos datasets ya que no es el objetivo de este EDA solo sirven como complemento a el primer dataset proporcionado con el nombre HOMICIDIOS

# %% [markdown]
# aclaracion: aun asi se deja estos calculos si se desea hacer una comparativa con el dataset anterior, no se habla de los primeros 2 datasets por que ya se hablo de que hay una diferencia muy grande a los datos de los primeros 2 datasets y los ultimos 2 respecto a datos e informacion que llevan

# %%
haniod=hanio.describe()
haniod
# Out:
#        cantidad_victimas  cantidad_victimas_masc  cantidad_victimas_fem  \
# count          23.000000               23.000000              23.000000
# mean       334808.086957           140700.043478          117837.782609
# std         54633.324367            24320.064269           40814.673706
# min        245383.000000            97378.000000           72766.000000
# 25%        297731.000000           117794.000000           82433.500000
# 50%        335657.000000           143769.000000          103763.000000
# 75%        389168.000000           161782.500000          155060.000000
# max        424151.000000           174823.000000          208075.000000
#
#        cantidad_victimas_sd  tasa_victimas  tasa_victimas_masc  \
# count              23.00000      23.000000           23.000000
# mean            76270.73913   21004.506487        17617.939555
# std             27536.38895    1876.043289         1475.121611
# min             48487.00000   17273.086074        14942.100023
# ...

# %%
pvictimas=haniod[['cantidad_victimas', 'cantidad_victimas_masc', 'cantidad_victimas_fem']]

# %%
pvictimas.plot(kind='bar')
plt.style.use("fivethirtyeight")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # ANALISIS FINAL

# %% [markdown]
# conclusion: tomando unicamente los datos de la ciudad de BUENOS AIRES DE LOS años 2016 - 2021 se puede ver que los datos oficiales muestran que hay una cantidad de datos que no contiene nuestro dataset principal asi que por eso mismo se hiso un ligero analisis con estos 2 ultimos datasets para dar una idea de la situacion en Argentina en general y se dejo para el final este analisis ya que se considero necesario por lo menos observar la demas informacion antes de sacar una conclucion sin fundamentos

# %%
conclusion=dfh3[dfh3['codigo_delito_snic_nombre']=='Muertes en accidentes viales']
conclusionciudad=conclusion[conclusion['provincia_nombre']=='Buenos Aires'][16:22]
conclusion=conclusionciudad[['provincia_nombre', 'codigo_delito_snic_nombre', 'cantidad_victimas', 'cantidad_victimas_masc', 'cantidad_victimas_fem', 'cantidad_victimas_sd']].groupby(['provincia_nombre']).sum()
pd.DataFrame(conclusion)
# Out:
#                                           codigo_delito_snic_nombre  \
# provincia_nombre
# Buenos Aires      Muertes en accidentes vialesMuertes en acciden...
#
#                   cantidad_victimas  cantidad_victimas_masc  \
# provincia_nombre
# Buenos Aires                 6180.0                  4469.0
#
#                   cantidad_victimas_fem  cantidad_victimas_sd
# provincia_nombre
# Buenos Aires                     1287.0                 424.0

# %% [markdown]
# # Conclusion final

# %% [markdown]
# El analisis de los 2 primeros datasets por el nombre de los mismos y nombres de los mismos no se pudo encontrar una relacion directa solo que ocurrieron en lugares viales
#
# Con la informacion oficial y la consulta hecha en el Analisis final que es anterior a este comentario, se puede ver el diferente contenido de los datos y que el gobierno si maneja una diferencia entre el termino HOMICIDIO y muerte por Accidentes Viales
#
# Llegando a la conclusion final de que todo el analisis hecho en este EDA es necesario para darse una idea del contenido del primer dataset que es nuestro dataset principal pero no se puede afirmar algo con total seguridad en nuestro primer dataset.
